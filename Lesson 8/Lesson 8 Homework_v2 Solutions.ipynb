# %% [markdown]
# # Homework Lesson 8

# %% [markdown]
# ### BigQuery and Colab
# Based on the tutorial in class, please do the following:
#
# - Open a Colab notebook
# - Authenticate into Google Cloud
# - Run a Bigquery SQL Query
# - Save the query to a dataframe
# - Display the first 5 rows of this DataFrame

# %% [markdown]
# ### Matplotlib

# %% [markdown]
# **Import Matplotlib and set %matplotlib inline**

# %%
#Your code here
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Use the following data to create plots**

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ## Exercise 1
#
# **Follow along with these steps:**
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
# Your code here
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)
ax.set_title('title')
ax.set_ylabel('y')
ax.set_xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# **Follow along with these steps:**

# %% [markdown]
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
#Your Code Here
fig = plt.figure()
axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
# Your code here
axes1.plot(x,y)
axes2.plot(x,y)



# Show figure object
fig

# %% [markdown]
# ## Exercise 3
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
# Empty canvas of 1 by 2 subplots
#Your Code here
# Empty canvas of 1 by 2 subplots
fig, axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
#Your Code Here
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') # More on color options later
plt.subplot(1,2,2)
plt.plot(x, z, 'g*-');
