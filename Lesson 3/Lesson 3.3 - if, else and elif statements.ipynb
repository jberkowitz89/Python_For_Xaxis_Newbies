# %% [markdown]
# # if, elif, else Statements
# <code>if</code> Statements in Python helps us tell the computer to perform alternative actions based on a certain set of results.
# <br>
# Imagine we're telling the computer:
# <br>
# <br>
# "If this happens, do this!"
# <br>
# <br>
# We can expand the idea further with <code>elif</code> and <code>else</code> statements, which allow us to tell the computer:
# <br>
# <br>
# "Hey, if this case happens, perform some action. Else, if another case happens, perform some other action. Else, if none of the above cases happened, perform this action."
# <br>
# <br>
# Let's go ahead and look at the syntax format for <code>if</code> statements to get a better idea of this:
#
#     if case1:
#         perform action1
#     elif case2:
#         perform action2
#     else:
#         perform action3
# <br>
# If you've ever used Case statements in SQL or if/ifelse statements in Excel, these operate very similarly.

# %% [markdown]
# ## Example 1
# Let's take a look at a quick example of this:

# %%
x = False
if x:
    print('It was true!')

# %% [markdown]
# Let's add in some more logic:

# %%
x = False

if x:
    print('x was True!')
else:
    print('I will be printed in any case where x is not true')
# Out:
# I will be printed in any case where x is not true

# %% [markdown]
# ### Multiple Branches

# %% [markdown]
# Let's get a bigger picture of how far <code>if</code>, <code>elif</code> and <code>else</code> can take us.
# <br>
# These are written in a nested structure. Take note of the whitespace and how <code>if</code>, <code>elif</code> and <code>else</code> line up. This can help you see what statements are related to each other with in your <code>if, else, elif</code> statements.

# %%
location = "Bank"

if location == "Auto Shop":
    print("Welcome to the Auto Shop!")
elif location == "Bank":
    print('Welcome to the bank!')
else:
    print("Where are you?")
# Out:
# Welcome to the bank!

# %% [markdown]
# Notice how the nested <code>if</code> statements are checked until a True boolean causes the nested code below it to run. Also note that you can put in as many <code>elif</code> statementsas you want before you close off with an <code>else</code>.
# <br>
# Let's go through a couple more simple examples for the <code>if</code>, <code>elif</code> and <code>else</code> statements:

# %%
person = "Sammy"

if person == "Sammy":
    print("Welcome Sammy!")
else:
    print("Welcome, what is your name?")
# Out:
# Welcome Sammy!

# %%
person = 'Fred'

if person == "Sammy":
    print('Welcome Sammy')
elif person == "George":
    print('Welcome George!')
else:
    print("Welcome, what's your name?")
# Out:
# Welcome, what's your name?

# %% [markdown]
# ### Conditionals with Lists and Dictionaries

# %% [markdown]
# Conditionals can also be used with Lists and Dictionaries. <br>
# A popular usage is the in/not in operator, which is used exactly as it sounds - to check whether an item is or is not in a List or Dictionary. <br>
# Let's look at some examples:

# %%
lst1 = [1, "two", "buckle", "my", "shoe"]

if "two" in lst1:
    print("Two is in!")
# Out:
# Two is in!

# %%
lst2 = [3, 4, "shut", "the", "door"]

if "buckle" not in lst2:
    print("You still have to buckle my shoe!")
else:
    "Let's shut the door!"
# Out:
# You still have to buckle my shoe!

# %%
dict1 = {"k1": "fun", "k2": "boo", "k3":"wee"}

if "fun" in dict1.keys():
    print("I found the fun!")
else:
    print("I couldn't find the key")
# Out:
# I couldn't find the key

# %% [markdown]
# ### Indentation
# It is important to keep an understanding of how indentation works in Python to maintain the structure and order of your code. We'll touch on this topic again when we start building out functions.
